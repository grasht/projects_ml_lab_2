# %% [markdown]
# <a href="https://colab.research.google.com/github/grasht/projects_ml_lab_2/blob/main/Lab2_02_training_clinic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  (training curves, overfitting control, instability debugging, experiment log)
