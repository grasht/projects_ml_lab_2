# %% [markdown]
# <a href="https://colab.research.google.com/github/grasht/projects_ml_lab_2/blob/main/Lab2_01_data_and_baselines.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# (dataset card + leakage checks + MLP baseline)

# %%
import os
import pandas as pd

# %%
os.listdir('inertial_signals')
# Out:
# ['body_gyro_x_train.txt',
#  'total_acc_y_train.txt',
#  'total_acc_z_train.txt',
#  'total_acc_x_train.txt',
#  'body_acc_y_train.txt',
#  'body_gyro_z_train.txt',
#  'body_gyro_y_train.txt',
#  'body_acc_z_train.txt']

# %%
df1 = pd.read_
